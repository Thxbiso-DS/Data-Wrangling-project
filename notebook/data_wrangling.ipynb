# %% [markdown]
# # __DATA WRANGLING (247): Using personality scores and department information to demonstrate how to manipulate data frames__

# %% [markdown]
# # 0. Introduction
#
# This project will focus on working with dataframes using pandas. It will focus on the following key concepts:
# * merging data frames
# * filtering data frames
# * manipulating rows and columns

# %% [markdown]
# ___

# %% [markdown]
# # 1.Initializing Project: Library Setup and Data Cleaning

# %% [markdown]
# ## 1.1 Import required libraries

# %%
import pandas as pd
import ast
import re

# %% [markdown]
# ## 1.2 Data cleaning

# %%
personality_df = pd.read_csv("../data/personality_scores.csv", sep=';')

personality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1555 entries, 0 to 1554
# Data columns (total 70 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   ID                                                                        1555 non-null   int64
#  1   Section 5 of 6 [I am always prepared.]                                    1555 non-null   object
#  2   Section 5 of 6 [I am easily disturbed.]                                   1555 non-null   object
#  3   Section 5 of 6 [I am exacting (demanding) in my work.]                    1555 non-null   object
#  4   Section 5 of 6 [I am full of ideas.]                                      1555 non-null   object
#  5   Section 5 of 6 [I am interested in people.]                               1555 non-null   object
#  6   Section 5 of 6 [I am not interested in abstract ideas.]                   1555 non-null   object
#  7   Section 5 of 6 [I am not interested in other people's problems.]          1555 non-null   object
#  8   Section 5 of 6 [I am not really interested in others.]                    1555 non-null   object
#  9   Section 5 of 6 [I am quick to understand things.]                         1555 non-null   object
#  10  Section 5 of 6 [I am quiet around strangers.]                             1555 non-null   object
#  11  Section 5 of 6 [I am relaxed most of the time.]                           1555 non-null   object
#  12  Section 5 of 6 [I am the life of the party.]                              1555 non-null   object
#  13  Section 5 of 6 [I change my mood a lot.]                                  1555 non-null   object
#  14  Section 5 of 6 [I do not have a good imagination.]                        1555 non-null   object
#  15  Section 5 of 6 [I don't like to draw attention to myself.]                1555 non-null   object
#  16  Section 5 of 6 [I don't mind being the center of attention.]              1555 non-null   object
#  17  Section 5 of 6 [I don't talk a lot.]                                      1555 non-null   object
#  18  Section 5 of 6 [I feel comfortable around people.]                        1555 non-null   object
#  19  Section 5 of 6 [I feel little concern for others.]                        1555 non-null   object
#  20  Section 5 of 6 [I feel others' emotions.]                                 1555 non-null   object
#  21  Section 5 of 6 [I follow a schedule.]                                     1555 non-null   object
#  22  Section 5 of 6 [I get chores done right away.]                            1555 non-null   object
#  23  Section 5 of 6 [I get irritated easily.]                                  1555 non-null   object
#  24  Section 5 of 6 [I get stressed out easily.]                               1555 non-null   object
#  25  Section 5 of 6 [I get upset easily.]                                      1555 non-null   object
#  26  Section 5 of 6 [I have a rich vocabulary.]                                1555 non-null   object
#  27  Section 5 of 6 [I have a soft (kind) heart.]                              1555 non-null   object
#  28  Section 5 of 6 [I have a vivid imagination.]                              1555 non-null   object
#  29  Section 5 of 6 [I have difficulty understanding abstract ideas.]          1555 non-null   object
#  30  Section 5 of 6 [I have excellent ideas.]                                  1555 non-null   object
#  31  Section 5 of 6 [I have frequent mood swings.]                             1555 non-null   object
#  32  Section 5 of 6 [I have little to say.]                                    1555 non-null   object
#  33  Section 5 of 6 [I insult people.]                                         1555 non-null   object
#  34  Section 5 of 6 [I keep in the background.]                                1555 non-null   object
#  35  Section 5 of 6 [I leave my belongings lying around.]                      1555 non-null   object
#  36  Section 5 of 6 [I like order.]                                            1555 non-null   object
#  37  Section 5 of 6 [I make a mess of things.]                                 1555 non-null   object
#  38  Section 5 of 6 [I make people feel at ease.]                              1555 non-null   object
#  39  Section 5 of 6 [I neglect my duties.]                                     1555 non-null   object
#  40  Section 5 of 6 [I often feel blue (down).]                                1555 non-null   object
#  41  Section 5 of 6 [I often forget to put things back in their proper place]  1555 non-null   object
#  42  Section 5 of 6 [I pay attention to details.]                              1555 non-null   object
#  43  Section 5 of 6 [I seldom feel blue (down).]                               1555 non-null   object
#  44  Section 5 of 6 [I spend time reflecting on things.]                       1555 non-null   object
#  45  Section 5 of 6 [I start conversations.]                                   1555 non-null   object
#  46  Section 5 of 6 [I sympathize with others' feelings.]                      1555 non-null   object
#  47  Section 5 of 6 [I take time out for others.]                              1555 non-null   object
#  48  Section 5 of 6 [I talk to a lot of different people at parties.]          1555 non-null   object
#  49  Section 5 of 6 [I use difficult words.]                                   1555 non-null   object
#  50  Section 5 of 6 [I worry about things.]                                    1555 non-null   object
#  51  Unnamed: 51                                                               0 non-null      float64
#  52  Unnamed: 52                                                               0 non-null      float64
#  53  Unnamed: 53                                                               0 non-null      float64
#  54  Unnamed: 54                                                               0 non-null      float64
#  55  Unnamed: 55                                                               0 non-null      float64
#  56  Unnamed: 56                                                               0 non-null      float64
#  57  Unnamed: 57                                                               0 non-null      float64
#  58  Unnamed: 58                                                               0 non-null      float64
#  59  Unnamed: 59                                                               0 non-null      float64
#  60  Unnamed: 60                                                               0 non-null      float64
#  61  Unnamed: 61                                                               0 non-null      float64
#  62  Unnamed: 62                                                               0 non-null      float64
#  63  Unnamed: 63                                                               0 non-null      float64
#  64  Unnamed: 64                                                               0 non-null      float64
#  65  Unnamed: 65                                                               0 non-null      float64
#  66  Unnamed: 66                                                               0 non-null      float64
#  67  Unnamed: 67                                                               0 non-null      float64
#  68  Unnamed: 68                                                               0 non-null      float64
#  69  IPIP_HIGH_RISK                                                            0 non-null      float64
# dtypes: float64(19), int64(1), object(50)
# memory usage: 850.5+ KB

# %% [markdown]
# There appears to be some unnamed columns with only nan values. These will be dropped

# %%
personality_df = personality_df.dropna(axis=1)

personality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1555 entries, 0 to 1554
# Data columns (total 51 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   ID                                                                        1555 non-null   int64
#  1   Section 5 of 6 [I am always prepared.]                                    1555 non-null   object
#  2   Section 5 of 6 [I am easily disturbed.]                                   1555 non-null   object
#  3   Section 5 of 6 [I am exacting (demanding) in my work.]                    1555 non-null   object
#  4   Section 5 of 6 [I am full of ideas.]                                      1555 non-null   object
#  5   Section 5 of 6 [I am interested in people.]                               1555 non-null   object
#  6   Section 5 of 6 [I am not interested in abstract ideas.]                   1555 non-null   object
#  7   Section 5 of 6 [I am not interested in other people's problems.]          1555 non-null   object
#  8   Section 5 of 6 [I am not really interested in others.]                    1555 non-null   object
#  9   Section 5 of 6 [I am quick to understand things.]                         1555 non-null   object
#  10  Section 5 of 6 [I am quiet around strangers.]                             1555 non-null   object
#  11  Section 5 of 6 [I am relaxed most of the time.]                           1555 non-null   object
#  12  Section 5 of 6 [I am the life of the party.]                              1555 non-null   object
#  13  Section 5 of 6 [I change my mood a lot.]                                  1555 non-null   object
#  14  Section 5 of 6 [I do not have a good imagination.]                        1555 non-null   object
#  15  Section 5 of 6 [I don't like to draw attention to myself.]                1555 non-null   object
#  16  Section 5 of 6 [I don't mind being the center of attention.]              1555 non-null   object
#  17  Section 5 of 6 [I don't talk a lot.]                                      1555 non-null   object
#  18  Section 5 of 6 [I feel comfortable around people.]                        1555 non-null   object
#  19  Section 5 of 6 [I feel little concern for others.]                        1555 non-null   object
#  20  Section 5 of 6 [I feel others' emotions.]                                 1555 non-null   object
#  21  Section 5 of 6 [I follow a schedule.]                                     1555 non-null   object
#  22  Section 5 of 6 [I get chores done right away.]                            1555 non-null   object
#  23  Section 5 of 6 [I get irritated easily.]                                  1555 non-null   object
#  24  Section 5 of 6 [I get stressed out easily.]                               1555 non-null   object
#  25  Section 5 of 6 [I get upset easily.]                                      1555 non-null   object
#  26  Section 5 of 6 [I have a rich vocabulary.]                                1555 non-null   object
#  27  Section 5 of 6 [I have a soft (kind) heart.]                              1555 non-null   object
#  28  Section 5 of 6 [I have a vivid imagination.]                              1555 non-null   object
#  29  Section 5 of 6 [I have difficulty understanding abstract ideas.]          1555 non-null   object
#  30  Section 5 of 6 [I have excellent ideas.]                                  1555 non-null   object
#  31  Section 5 of 6 [I have frequent mood swings.]                             1555 non-null   object
#  32  Section 5 of 6 [I have little to say.]                                    1555 non-null   object
#  33  Section 5 of 6 [I insult people.]                                         1555 non-null   object
#  34  Section 5 of 6 [I keep in the background.]                                1555 non-null   object
#  35  Section 5 of 6 [I leave my belongings lying around.]                      1555 non-null   object
#  36  Section 5 of 6 [I like order.]                                            1555 non-null   object
#  37  Section 5 of 6 [I make a mess of things.]                                 1555 non-null   object
#  38  Section 5 of 6 [I make people feel at ease.]                              1555 non-null   object
#  39  Section 5 of 6 [I neglect my duties.]                                     1555 non-null   object
#  40  Section 5 of 6 [I often feel blue (down).]                                1555 non-null   object
#  41  Section 5 of 6 [I often forget to put things back in their proper place]  1555 non-null   object
#  42  Section 5 of 6 [I pay attention to details.]                              1555 non-null   object
#  43  Section 5 of 6 [I seldom feel blue (down).]                               1555 non-null   object
#  44  Section 5 of 6 [I spend time reflecting on things.]                       1555 non-null   object
#  45  Section 5 of 6 [I start conversations.]                                   1555 non-null   object
#  46  Section 5 of 6 [I sympathize with others' feelings.]                      1555 non-null   object
#  47  Section 5 of 6 [I take time out for others.]                              1555 non-null   object
#  48  Section 5 of 6 [I talk to a lot of different people at parties.]          1555 non-null   object
#  49  Section 5 of 6 [I use difficult words.]                                   1555 non-null   object
#  50  Section 5 of 6 [I worry about things.]                                    1555 non-null   object
# dtypes: int64(1), object(50)
# memory usage: 619.7+ KB

# %% [markdown]
# After dropping the columns with null values, it would be suitable to provide a summary of the table to get an idea of what the dataframe looks like.

# %%
personality_df.head(10)
# Out:
#    ID Section 5 of 6 [I am always prepared.]  \
# 0   0                                 (3, 5)
# 1   1                                 (3, 5)
# 2   2                                 (3, 5)
# 3   3                                 (3, 5)
# 4   4                                 (3, 3)
# 5   5                                 (3, 5)
# 6   6                                 (3, 5)
# 7   7                                 (3, 5)
# 8   8                                 (3, 5)
# 9   9                                 (3, 3)
#
#   Section 5 of 6 [I am easily disturbed.]  \
# 0                                  (4, 5)
# 1                                  (4, 5)
# 2                                  (4, 3)
# 3                                  (4, 5)
# 4                                  (4, 5)
# 5                                  (4, 5)
# 6                                  (4, 5)
# 7                                  (4, 5)
# 8                                  (4, 5)
# 9                                  (4, 3)
#
#   Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
# 2                                             (3, 3)
# 3                                             (3, 3)
# 4                                             (3, 3)
# 5                                             (3, 3)
# 6                                             (3, 5)
# 7                                             (3, 3)
# 8                                             (3, 5)
# 9                                             (3, 3)
#
#   Section 5 of 6 [I am full of ideas.]  \
# 0                               (5, 5)
# 1                               (5, 5)
# 2                               (5, 5)
# 3                               (5, 5)
# 4                               (5, 3)
# 5                               (5, 5)
# 6                               (5, 5)
# 7                               (5, 5)
# 8                               (5, 5)
# 9                               (5, 5)
#
#   Section 5 of 6 [I am interested in people.]  \
# 0                                      (2, 3)
# 1                                      (2, 5)
# 2                                      (2, 5)
# 3                                      (2, 5)
# 4                                      (2, 3)
# 5                                      (2, 5)
# 6                                      (2, 5)
# 7                                      (2, 5)
# 8                                      (2, 5)
# 9                                      (2, 5)
#
#   Section 5 of 6 [I am not interested in abstract ideas.]  \
# 0                                             (5, 3)
# 1                                             (5, 3)
# 2                                             (5, 5)
# 3                                             (5, 3)
# 4                                             (5, 3)
# 5                                             (5, 3)
# 6                                             (5, 3)
# 7                                             (5, 5)
# 8                                             (5, 5)
# 9                                             (5, 3)
#
#   Section 5 of 6 [I am not interested in other people's problems.]  \
# 0                                             (2, 3)
# 1                                             (2, 5)
# 2                                             (2, 5)
# 3                                             (2, 3)
# 4                                             (2, 3)
# 5                                             (2, 5)
# 6                                             (2, 5)
# 7                                             (2, 5)
# 8                                             (2, 5)
# 9                                             (2, 5)
#
#   Section 5 of 6 [I am not really interested in others.]  \
# 0                                             (2, 5)
# 1                                             (2, 5)
# 2                                             (2, 5)
# 3                                             (2, 3)
# 4                                             (2, 3)
# 5                                             (2, 5)
# 6                                             (2, 5)
# 7                                             (2, 5)
# 8                                             (2, 5)
# 9                                             (2, 3)
#
#   Section 5 of 6 [I am quick to understand things.]  ...  \
# 0                                            (5, 5)  ...
# 1                                            (5, 5)  ...
# 2                                            (5, 5)  ...
# 3                                            (5, 3)  ...
# 4                                            (5, 5)  ...
# 5                                            (5, 5)  ...
# 6                                            (5, 5)  ...
# 7                                            (5, 5)  ...
# 8                                            (5, 5)  ...
# 9                                            (5, 5)  ...
#
#   Section 5 of 6 [I often forget to put things back in their proper place]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
# 2                                             (3, 5)
# 3                                             (3, 1)
# 4                                             (3, 5)
# 5                                             (3, 3)
# 6                                             (3, 5)
# 7                                             (3, 5)
# 8                                             (3, 5)
# 9                                             (3, 3)
#
#   Section 5 of 6 [I pay attention to details.]  \
# 0                                       (3, 5)
# 1                                       (3, 1)
# 2                                       (3, 5)
# 3                                       (3, 5)
# 4                                       (3, 5)
# 5                                       (3, 5)
# 6                                       (3, 5)
# 7                                       (3, 5)
# 8                                       (3, 5)
# 9                                       (3, 5)
#
#   Section 5 of 6 [I seldom feel blue (down).]  \
# 0                                      (4, 3)
# 1                                      (4, 1)
# 2                                      (4, 1)
# 3                                      (4, 1)
# 4                                      (4, 5)
# 5                                      (4, 5)
# 6                                      (4, 3)
# 7                                      (4, 3)
# 8                                      (4, 1)
# 9                                      (4, 1)
#
#   Section 5 of 6 [I spend time reflecting on things.]  \
# 0                                             (5, 5)
# 1                                             (5, 5)
# 2                                             (5, 3)
# 3                                             (5, 5)
# 4                                             (5, 5)
# 5                                             (5, 5)
# 6                                             (5, 5)
# 7                                             (5, 3)
# 8                                             (5, 5)
# 9                                             (5, 5)
#
#   Section 5 of 6 [I start conversations.]  \
# 0                                  (1, 3)
# 1                                  (1, 5)
# 2                                  (1, 3)
# 3                                  (1, 5)
# 4                                  (1, 3)
# 5                                  (1, 5)
# 6                                  (1, 5)
# 7                                  (1, 5)
# 8                                  (1, 5)
# 9                                  (1, 5)
#
#   Section 5 of 6 [I sympathize with others' feelings.]  \
# 0                                             (2, 5)
# 1                                             (2, 5)
# 2                                             (2, 5)
# 3                                             (2, 5)
# 4                                             (2, 3)
# 5                                             (2, 5)
# 6                                             (2, 5)
# 7                                             (2, 5)
# 8                                             (2, 5)
# 9                                             (2, 5)
#
#   Section 5 of 6 [I take time out for others.]  \
# 0                                       (2, 5)
# 1                                       (2, 5)
# 2                                       (2, 5)
# 3                                       (2, 5)
# 4                                       (2, 5)
# 5                                       (2, 5)
# 6                                       (2, 5)
# 7                                       (2, 3)
# 8                                       (2, 1)
# 9                                       (2, 5)
#
#   Section 5 of 6 [I talk to a lot of different people at parties.]  \
# 0                                             (1, 3)
# 1                                             (1, 5)
# 2                                             (1, 3)
# 3                                             (1, 5)
# 4                                             (1, 3)
# 5                                             (1, 5)
# 6                                             (1, 5)
# 7                                             (1, 5)
# 8                                             (1, 5)
# 9                                             (1, 5)
#
#   Section 5 of 6 [I use difficult words.]  \
# 0                                  (5, 1)
# 1                                  (5, 3)
# 2                                  (5, 1)
# 3                                  (5, 1)
# 4                                  (5, 1)
# 5                                  (5, 3)
# 6                                  (5, 3)
# 7                                  (5, 1)
# 8                                  (5, 3)
# 9                                  (5, 5)
#
#   Section 5 of 6 [I worry about things.]
# 0                                 (4, 3)
# 1                                 (4, 3)
# 2                                 (4, 3)
# 3                                 (4, 1)
# 4                                 (4, 3)
# 5                                 (4, 1)
# 6                                 (4, 1)
# 7                                 (4, 3)
# 8                                 (4, 3)
# 9                                 (4, 1)
#
# [10 rows x 51 columns]

# %% [markdown]
# The next part of the cleaning process will be to fix the column names to only have the text in brackets appear.

# %%
column_name_pattern = r"\[([^[\]]+)\]"


columns_with_section_in_title = personality_df.columns[1:].str.extract(column_name_pattern).iloc[:, 0]
columns_with_section_in_title = columns_with_section_in_title.str.replace(".", " ")
personality_df.columns = [personality_df.columns[0]] + list(columns_with_section_in_title)
personality_score_df = personality_df

personality_score_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1555 entries, 0 to 1554
# Data columns (total 51 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   ID                                                       1555 non-null   int64
#  1   I am always prepared                                     1555 non-null   object
#  2   I am easily disturbed                                    1555 non-null   object
#  3   I am exacting (demanding) in my work                     1555 non-null   object
#  4   I am full of ideas                                       1555 non-null   object
#  5   I am interested in people                                1555 non-null   object
#  6   I am not interested in abstract ideas                    1555 non-null   object
#  7   I am not interested in other people's problems           1555 non-null   object
#  8   I am not really interested in others                     1555 non-null   object
#  9   I am quick to understand things                          1555 non-null   object
#  10  I am quiet around strangers                              1555 non-null   object
#  11  I am relaxed most of the time                            1555 non-null   object
#  12  I am the life of the party                               1555 non-null   object
#  13  I change my mood a lot                                   1555 non-null   object
#  14  I do not have a good imagination                         1555 non-null   object
#  15  I don't like to draw attention to myself                 1555 non-null   object
#  16  I don't mind being the center of attention               1555 non-null   object
#  17  I don't talk a lot                                       1555 non-null   object
#  18  I feel comfortable around people                         1555 non-null   object
#  19  I feel little concern for others                         1555 non-null   object
#  20  I feel others' emotions                                  1555 non-null   object
#  21  I follow a schedule                                      1555 non-null   object
#  22  I get chores done right away                             1555 non-null   object
#  23  I get irritated easily                                   1555 non-null   object
#  24  I get stressed out easily                                1555 non-null   object
#  25  I get upset easily                                       1555 non-null   object
#  26  I have a rich vocabulary                                 1555 non-null   object
#  27  I have a soft (kind) heart                               1555 non-null   object
#  28  I have a vivid imagination                               1555 non-null   object
#  29  I have difficulty understanding abstract ideas           1555 non-null   object
#  30  I have excellent ideas                                   1555 non-null   object
#  31  I have frequent mood swings                              1555 non-null   object
#  32  I have little to say                                     1555 non-null   object
#  33  I insult people                                          1555 non-null   object
#  34  I keep in the background                                 1555 non-null   object
#  35  I leave my belongings lying around                       1555 non-null   object
#  36  I like order                                             1555 non-null   object
#  37  I make a mess of things                                  1555 non-null   object
#  38  I make people feel at ease                               1555 non-null   object
#  39  I neglect my duties                                      1555 non-null   object
#  40  I often feel blue (down)                                 1555 non-null   object
#  41  I often forget to put things back in their proper place  1555 non-null   object
#  42  I pay attention to details                               1555 non-null   object
#  43  I seldom feel blue (down)                                1555 non-null   object
#  44  I spend time reflecting on things                        1555 non-null   object
#  45  I start conversations                                    1555 non-null   object
#  46  I sympathize with others' feelings                       1555 non-null   object
#  47  I take time out for others                               1555 non-null   object
#  48  I talk to a lot of different people at parties           1555 non-null   object
#  49  I use difficult words                                    1555 non-null   object
#  50  I worry about things                                     1555 non-null   object
# dtypes: int64(1), object(50)
# memory usage: 619.7+ KB

# %% [markdown]
# All the text outside the square parenthesis have been removed and the dataframe has been cleaned enough to begin the process of wrangking the data.

# %% [markdown]
# ___

# %% [markdown]
# # 2. Assignment

# %% [markdown]
# * ### Examining the personality scores csv for any duplicates and removing any that exist.

# %%
assert len(personality_score_df) == personality_df.ID.nunique(), "Dataframe lengths do not match"

# %% [markdown]
# The code above also includes an assert statement to check that the new data frame is the length of the unique entries of the original data frame.

# %% [markdown]
# * ### Creating new columns for the personality test subscales.

# %% [markdown]
# To create new columns containing the total score of each personality test subscale, the new columns need to be inserted into the dataframe.

# %%
personality_traits = ['Conscientiousness', 'Emotional_Stability', 'Openness', 'Agreeable', 'Extraversion'] 

new_columns = {personality_trait: 0 for personality_trait in personality_traits}

personality_score_totals_df = pd.concat([personality_score_df, pd.DataFrame(new_columns, index=personality_score_df.index)], axis=1)

# %%
personality_score_totals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1555 entries, 0 to 1554
# Data columns (total 56 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   ID                                                       1555 non-null   int64
#  1   I am always prepared                                     1555 non-null   object
#  2   I am easily disturbed                                    1555 non-null   object
#  3   I am exacting (demanding) in my work                     1555 non-null   object
#  4   I am full of ideas                                       1555 non-null   object
#  5   I am interested in people                                1555 non-null   object
#  6   I am not interested in abstract ideas                    1555 non-null   object
#  7   I am not interested in other people's problems           1555 non-null   object
#  8   I am not really interested in others                     1555 non-null   object
#  9   I am quick to understand things                          1555 non-null   object
#  10  I am quiet around strangers                              1555 non-null   object
#  11  I am relaxed most of the time                            1555 non-null   object
#  12  I am the life of the party                               1555 non-null   object
#  13  I change my mood a lot                                   1555 non-null   object
#  14  I do not have a good imagination                         1555 non-null   object
#  15  I don't like to draw attention to myself                 1555 non-null   object
#  16  I don't mind being the center of attention               1555 non-null   object
#  17  I don't talk a lot                                       1555 non-null   object
#  18  I feel comfortable around people                         1555 non-null   object
#  19  I feel little concern for others                         1555 non-null   object
#  20  I feel others' emotions                                  1555 non-null   object
#  21  I follow a schedule                                      1555 non-null   object
#  22  I get chores done right away                             1555 non-null   object
#  23  I get irritated easily                                   1555 non-null   object
#  24  I get stressed out easily                                1555 non-null   object
#  25  I get upset easily                                       1555 non-null   object
#  26  I have a rich vocabulary                                 1555 non-null   object
#  27  I have a soft (kind) heart                               1555 non-null   object
#  28  I have a vivid imagination                               1555 non-null   object
#  29  I have difficulty understanding abstract ideas           1555 non-null   object
#  30  I have excellent ideas                                   1555 non-null   object
#  31  I have frequent mood swings                              1555 non-null   object
#  32  I have little to say                                     1555 non-null   object
#  33  I insult people                                          1555 non-null   object
#  34  I keep in the background                                 1555 non-null   object
#  35  I leave my belongings lying around                       1555 non-null   object
#  36  I like order                                             1555 non-null   object
#  37  I make a mess of things                                  1555 non-null   object
#  38  I make people feel at ease                               1555 non-null   object
#  39  I neglect my duties                                      1555 non-null   object
#  40  I often feel blue (down)                                 1555 non-null   object
#  41  I often forget to put things back in their proper place  1555 non-null   object
#  42  I pay attention to details                               1555 non-null   object
#  43  I seldom feel blue (down)                                1555 non-null   object
#  44  I spend time reflecting on things                        1555 non-null   object
#  45  I start conversations                                    1555 non-null   object
#  46  I sympathize with others' feelings                       1555 non-null   object
#  47  I take time out for others                               1555 non-null   object
#  48  I talk to a lot of different people at parties           1555 non-null   object
#  49  I use difficult words                                    1555 non-null   object
#  50  I worry about things                                     1555 non-null   object
#  51  Conscientiousness                                        1555 non-null   int64
#  52  Emotional_Stability                                      1555 non-null   int64
#  53  Openness                                                 1555 non-null   int64
#  54  Agreeable                                                1555 non-null   int64
#  55  Extraversion                                             1555 non-null   int64
# dtypes: int64(6), object(50)
# memory usage: 680.4+ KB

# %% [markdown]
# The new columns have been created successfully. However, the "info" attribute indicates that the data type of pre-existing columns, except the ID column, is "object". This type of data cannot be used for performing calculations. Therefore, it is necessary to convert the data type to a more suitable one before calculating.

# %%
personality_score_totals_df.iloc[:, :51] = personality_score_totals_df.iloc[:, :51].apply(lambda x: x.map(lambda y: ast.literal_eval(y) if isinstance(y, str) else y))

# %% [markdown]
# Now to confirm if the values were converted to tuple

# %%
subset_of_data_with_tuple = personality_score_totals_df.iloc[:,1:51]
all_tuples = True 

for col in subset_of_data_with_tuple.columns:
    for row in subset_of_data_with_tuple.index:
        value = subset_of_data_with_tuple.loc[row, col]
        if not isinstance(value, tuple):
            all_tuples = False
            break  

if all_tuples:
    print("All cells are tuples")
else:
    print("Not all cells are tuples")
# Out:
# All cells are tuples

# %% [markdown]
# The next step is creating and implementing the function that will add the values of the subscales to their descriptive columns.

# %%
def add_to_subscales(row):
    subscale_columns = {1: 'Extraversion', 2: 'Agreeable',3: 'Conscientiousness', 4: 'Emotional_Stability', 5: 'Openness'}
    subscale_totals = {trait: 0 for trait in personality_traits}

    for item_code, response in row[1:51]:
        subscale_code = subscale_columns.get(item_code)
        if subscale_code is not None:
            subscale_totals[subscale_code] += response
    
    return pd.Series(subscale_totals)

total_scores = personality_score_totals_df.apply(add_to_subscales, axis=1) 
personality_scores = personality_score_totals_df.drop(personality_traits, axis=1)

personality_score_totals_df = pd.concat([personality_scores, total_scores], axis=1)

personality_score_totals_df.head()
# Out:
#    ID I am always prepared  I am easily disturbed   \
# 0   0                (3, 5)                 (4, 5)
# 1   1                (3, 5)                 (4, 5)
# 2   2                (3, 5)                 (4, 3)
# 3   3                (3, 5)                 (4, 5)
# 4   4                (3, 3)                 (4, 5)
#
#   I am exacting (demanding) in my work  I am full of ideas   \
# 0                                (3, 5)              (5, 5)
# 1                                (3, 5)              (5, 5)
# 2                                (3, 3)              (5, 5)
# 3                                (3, 3)              (5, 5)
# 4                                (3, 3)              (5, 3)
#
#   I am interested in people  I am not interested in abstract ideas   \
# 0                     (2, 3)                                 (5, 3)
# 1                     (2, 5)                                 (5, 3)
# 2                     (2, 5)                                 (5, 5)
# 3                     (2, 5)                                 (5, 3)
# 4                     (2, 3)                                 (5, 3)
#
#   I am not interested in other people's problems   \
# 0                                          (2, 3)
# 1                                          (2, 5)
# 2                                          (2, 5)
# 3                                          (2, 3)
# 4                                          (2, 3)
#
#   I am not really interested in others  I am quick to understand things   ...  \
# 0                                (2, 5)                           (5, 5)  ...
# 1                                (2, 5)                           (5, 5)  ...
# 2                                (2, 5)                           (5, 5)  ...
# 3                                (2, 3)                           (5, 3)  ...
# 4                                (2, 3)                           (5, 5)  ...
#
#   I sympathize with others' feelings  I take time out for others   \
# 0                              (2, 5)                      (2, 5)
# 1                              (2, 5)                      (2, 5)
# 2                              (2, 5)                      (2, 5)
# 3                              (2, 5)                      (2, 5)
# 4                              (2, 3)                      (2, 5)
#
#   I talk to a lot of different people at parties  I use difficult words   \
# 0                                          (1, 3)                 (5, 1)
# 1                                          (1, 5)                 (5, 3)
# 2                                          (1, 3)                 (5, 1)
# 3                                          (1, 5)                 (5, 1)
# 4                                          (1, 3)                 (5, 1)
#
#   I worry about things  Conscientiousness Emotional_Stability Openness  \
# 0                (4, 3)                48                  36       42
# 1                (4, 3)                46                  40       42
# 2                (4, 3)                40                  38       42
# 3                (4, 1)                38                  40       38
# 4                (4, 3)                46                  38       36
#
#   Agreeable Extraversion
# 0        40           30
# 1        46           42
# 2        40           28
# 3        38           30
# 4        34           28
#
# [5 rows x 56 columns]

# %% [markdown]
# The summarized personality score dataframe shows the addition of 5 personality trait columns with the corresponding sum totals for each subscale.

# %% [markdown]
# ___

# %% [markdown]
# * ### Importing the departments.csv into a dataframe.
#
# The next step is to import the departments.csv file into a dataframe then followed by merging the dataframe with the personality score data frame, keeping all applicants within the department data frame.

# %% [markdown]
# The first step is importing the departments.csv dataframe

# %%
departments_df = pd.read_csv("../data/departments.csv", sep=';')

departments_df.head()
# Out:
#    ID Department
# 0   0       Data
# 1   1       Data
# 2   2       Data
# 3   3       Data
# 4   4       Data

# %% [markdown]
# The next step is displaying the different departments present.

# %%
list_of_departments = departments_df["Department"].unique()
list_of_departments
# Out:
# array(['Data', 'Web Dev', 'Copywriting', 'Design', 'Strategy', 'Web dev'],
#       dtype=object)

# %% [markdown]
# There appears to be a minor mistake in the departments entered where Web Dev and Web dev were taken as two separate departments. To fix this all occurrences of 'Web dev' will be replaced with 'Web Dev'.

# %%
departments_df['Department'] = departments_df['Department'].replace('Web dev', 'Web Dev', regex=True)
list_of_departments = departments_df["Department"].unique()
list_of_departments
# Out:
# array(['Data', 'Web Dev', 'Copywriting', 'Design', 'Strategy'],
#       dtype=object)

# %% [markdown]
# Now that the issue has been sorted, the two dataframes can be now be merged.
#
# The ‘departments’ dataframe has only 2 columns, ID and Department. The ID column is the only one that is common among the two so merging using the join() function is the best option.

# %%
merged_personality_department_df = personality_score_totals_df.merge(departments_df, on='ID', how='inner', suffixes=('_personality_score', '_department'))


assert len(merged_personality_department_df) == len(departments_df), "Dataframe rows are not the same"
expected_num_columns = len(personality_score_totals_df.columns) + len(departments_df.columns) - 1  # Subtract 1 for the overlapping column 'ID'
assert len(merged_personality_department_df.columns) == expected_num_columns, "Number of columns is not as expected"

# %% [markdown]
# The assert statement does not return any errors indicating that the dataframes have been successfully merged. Now observe what the merged dataframe looks like.

# %%
merged_personality_department_df.head()
# Out:
#    ID I am always prepared  I am easily disturbed   \
# 0   0                (3, 5)                 (4, 5)
# 1   1                (3, 5)                 (4, 5)
# 2   2                (3, 5)                 (4, 3)
# 3   3                (3, 5)                 (4, 5)
# 4   4                (3, 3)                 (4, 5)
#
#   I am exacting (demanding) in my work  I am full of ideas   \
# 0                                (3, 5)              (5, 5)
# 1                                (3, 5)              (5, 5)
# 2                                (3, 3)              (5, 5)
# 3                                (3, 3)              (5, 5)
# 4                                (3, 3)              (5, 3)
#
#   I am interested in people  I am not interested in abstract ideas   \
# 0                     (2, 3)                                 (5, 3)
# 1                     (2, 5)                                 (5, 3)
# 2                     (2, 5)                                 (5, 5)
# 3                     (2, 5)                                 (5, 3)
# 4                     (2, 3)                                 (5, 3)
#
#   I am not interested in other people's problems   \
# 0                                          (2, 3)
# 1                                          (2, 5)
# 2                                          (2, 5)
# 3                                          (2, 3)
# 4                                          (2, 3)
#
#   I am not really interested in others  I am quick to understand things   ...  \
# 0                                (2, 5)                           (5, 5)  ...
# 1                                (2, 5)                           (5, 5)  ...
# 2                                (2, 5)                           (5, 5)  ...
# 3                                (2, 3)                           (5, 3)  ...
# 4                                (2, 3)                           (5, 5)  ...
#
#   I take time out for others  I talk to a lot of different people at parties   \
# 0                      (2, 5)                                          (1, 3)
# 1                      (2, 5)                                          (1, 5)
# 2                      (2, 5)                                          (1, 3)
# 3                      (2, 5)                                          (1, 5)
# 4                      (2, 5)                                          (1, 3)
#
#   I use difficult words  I worry about things  Conscientiousness  \
# 0                 (5, 1)                (4, 3)                48
# 1                 (5, 3)                (4, 3)                46
# 2                 (5, 1)                (4, 3)                40
# 3                 (5, 1)                (4, 1)                38
# 4                 (5, 1)                (4, 3)                46
#
#   Emotional_Stability Openness Agreeable Extraversion Department
# 0                  36       42        40           30       Data
# 1                  40       42        46           42       Data
# 2                  38       42        40           28       Data
# 3                  40       38        38           30       Data
# 4                  38       36        34           28       Data
#
# [5 rows x 57 columns]

# %% [markdown]
# ___

# %% [markdown]
# * ### Filtering the data frame by applicants who scored less than 30 on Emotional Stability, Conscientiousness and Agreeableness.

# %% [markdown]
# The first step in this process is defining a function that checks whether the applicant scored less than 30 on Emotional Stability, Conscientiousness and Agreeableness, if this condition is met they are assigned the term "high_risk" in a new column called 'Risk tag' if they do not fall under these conditions they are assigned "low_risk".

# %%
def risk_assessment(row):
    high_risk_condition = (
        (row['Emotional_Stability'] < 30) &
        (row['Conscientiousness'] < 30) &
        (row['Agreeable'] < 30))

    return "high_risk" if high_risk_condition else "low_risk"

# %% [markdown]
# The next step involves creating a dataframe named "risk_status_df". This dataframe is a filtered version of the "merged_personality_department_df" dataframe that only displays the same results as merged_personality_department_df with the risk tag column as well. To get the risk tag, the risk_assessment function was applied to a column called "risk_tag_column" which displays the risk status from the "merged_personality_department_df" dataframe. The resulting column was merged with the merged_personality_department_df dataframe to create the risk_status_df dataframe.

# %%
risk_tag_column = merged_personality_department_df.apply(risk_assessment, axis=1)
risk_tag_column = risk_tag_column.rename('Risk Status')

risk_status_df =   pd.concat([merged_personality_department_df, risk_tag_column], axis=1)

risk_status_df.head(10)
# Out:
#    ID I am always prepared  I am easily disturbed   \
# 0   0                (3, 5)                 (4, 5)
# 1   1                (3, 5)                 (4, 5)
# 2   2                (3, 5)                 (4, 3)
# 3   3                (3, 5)                 (4, 5)
# 4   4                (3, 3)                 (4, 5)
# 5   5                (3, 5)                 (4, 5)
# 6   6                (3, 5)                 (4, 5)
# 7   7                (3, 5)                 (4, 5)
# 8   8                (3, 5)                 (4, 5)
# 9   9                (3, 3)                 (4, 3)
#
#   I am exacting (demanding) in my work  I am full of ideas   \
# 0                                (3, 5)              (5, 5)
# 1                                (3, 5)              (5, 5)
# 2                                (3, 3)              (5, 5)
# 3                                (3, 3)              (5, 5)
# 4                                (3, 3)              (5, 3)
# 5                                (3, 3)              (5, 5)
# 6                                (3, 5)              (5, 5)
# 7                                (3, 3)              (5, 5)
# 8                                (3, 5)              (5, 5)
# 9                                (3, 3)              (5, 5)
#
#   I am interested in people  I am not interested in abstract ideas   \
# 0                     (2, 3)                                 (5, 3)
# 1                     (2, 5)                                 (5, 3)
# 2                     (2, 5)                                 (5, 5)
# 3                     (2, 5)                                 (5, 3)
# 4                     (2, 3)                                 (5, 3)
# 5                     (2, 5)                                 (5, 3)
# 6                     (2, 5)                                 (5, 3)
# 7                     (2, 5)                                 (5, 5)
# 8                     (2, 5)                                 (5, 5)
# 9                     (2, 5)                                 (5, 3)
#
#   I am not interested in other people's problems   \
# 0                                          (2, 3)
# 1                                          (2, 5)
# 2                                          (2, 5)
# 3                                          (2, 3)
# 4                                          (2, 3)
# 5                                          (2, 5)
# 6                                          (2, 5)
# 7                                          (2, 5)
# 8                                          (2, 5)
# 9                                          (2, 5)
#
#   I am not really interested in others  I am quick to understand things   ...  \
# 0                                (2, 5)                           (5, 5)  ...
# 1                                (2, 5)                           (5, 5)  ...
# 2                                (2, 5)                           (5, 5)  ...
# 3                                (2, 3)                           (5, 3)  ...
# 4                                (2, 3)                           (5, 5)  ...
# 5                                (2, 5)                           (5, 5)  ...
# 6                                (2, 5)                           (5, 5)  ...
# 7                                (2, 5)                           (5, 5)  ...
# 8                                (2, 5)                           (5, 5)  ...
# 9                                (2, 3)                           (5, 5)  ...
#
#   I talk to a lot of different people at parties  I use difficult words   \
# 0                                          (1, 3)                 (5, 1)
# 1                                          (1, 5)                 (5, 3)
# 2                                          (1, 3)                 (5, 1)
# 3                                          (1, 5)                 (5, 1)
# 4                                          (1, 3)                 (5, 1)
# 5                                          (1, 5)                 (5, 3)
# 6                                          (1, 5)                 (5, 3)
# 7                                          (1, 5)                 (5, 1)
# 8                                          (1, 5)                 (5, 3)
# 9                                          (1, 5)                 (5, 5)
#
#   I worry about things  Conscientiousness Emotional_Stability Openness  \
# 0                (4, 3)                48                  36       42
# 1                (4, 3)                46                  40       42
# 2                (4, 3)                40                  38       42
# 3                (4, 1)                38                  40       38
# 4                (4, 3)                46                  38       36
# 5                (4, 1)                42                  46       36
# 6                (4, 1)                50                  36       42
# 7                (4, 3)                48                  42       42
# 8                (4, 3)                48                  44       48
# 9                (4, 1)                36                  18       42
#
#   Agreeable Extraversion Department Risk Status
# 0        40           30       Data    low_risk
# 1        46           42       Data    low_risk
# 2        40           28       Data    low_risk
# 3        38           30       Data    low_risk
# 4        34           28       Data    low_risk
# 5        46           48       Data    low_risk
# 6        44           38       Data    low_risk
# 7        48           30       Data    low_risk
# 8        46           40       Data    low_risk
# 9        44           32       Data    low_risk
#
# [10 rows x 58 columns]

# %% [markdown]
# The next step is to identitfy the high risk applicants from this dataframe.

# %%
high_risk_applicants_df = risk_status_df[risk_status_df["Risk Status"] == "high_risk"][["ID", "Department"]]

high_risk_applicants_df
# Out:
#         ID   Department
# 881    881         Data
# 1197  1197  Copywriting

# %% [markdown]
# The results of the filter show that only two applicants, applicant no. 881 in the data department and applicant no. 1197 in the copywriting department, are classified as 'high risk'.

# %% [markdown]
# ___

# %% [markdown]
# * ### Creating a new data frame with a count of the number of low and high-risk applicants within each department.

# %%
risk_status_summary_df = risk_status_df.groupby(['Risk Status', 'Department']).size().unstack(fill_value=0)
risk_status_summary_df.index.name = None
risk_status_summary_df.columns.name = 'Risk Status'

risk_status_summary_df = risk_status_summary_df.rename(index={'low_risk': 'Low risk', 'high_risk': 'High risk'})

risk_status_summary_df
# Out:
# Risk Status  Copywriting  Data  Design  Strategy  Web Dev
# High risk              1     1       0         0        0
# Low risk             325   328     120       449      331

# %% [markdown]
# ___

# %% [markdown]
# # 3. Conclusion
#
# The aim of this project was to showcase the different data wrangling skills by applying functions to a dataframe, filtering, sorting, and joining different dataframes together. This was achieved this by completing the exercises throughout this [page](http://syllabus.africacode.net/projects/data-science-specific/data-wrangling/).
